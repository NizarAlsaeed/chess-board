# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
class ChessBoard:
    def __init__(self):
        self.grid =  np.array([[[(i+j)%2 for k in range(3)] for i in range(8)] for j in range(8)]).astype('float32')
        
    def add_red (self,row,col):
        """accepts a row and column as input which colors corresponding cell."""
        red = (1,.2,0)
        self.grid[row,col] = red 
        
    def add_blue (self,row,col):
        """accepts a row and column as input which colors corresponding cell."""
        blue = (0,1,1)
        self.grid[row,col] = blue

    def render (self):
        """displays the chess board on screen with red and blue shown in correct locations"""
        plt.imshow(self.grid)

    def is_under_attack(self):
        """return boolean if red is under attack by a blue piece horizontally, vertically or                    diagonally"""
        pass

# %%
chess = ChessBoard()

# %%
plt.imshow(chess.grid)

#https://matplotlib.org/stable/gallery/images_contours_and_fields/layer_images.html#sphx-glr-gallery-images-contours-and-fields-layer-images-py

# %%
chess.add_red(4,4)
chess.add_blue(0,1)

# %%
chess.render()
